# %%
import pandas as pd
import requests
from datetime import datetime
import json

# %%
email = "zceimpo@ucl.ac.uk"
api = "EU7OWLtHsLaVApHo56AT"
url = f"https://api.acleddata.com/acled/read?key={api}&email={email}"

# %%
""" 
MENA Countries:
Iran - 364,
Israel - 376,
Lebanon - 422,
Palestine - 275,
Syria - 760,
Iraq - 368,
Turkey - 792,
Yemen - 887,
Egypt - 818,
Tunisia - 788,
"""
mena_iso = [364,376,422,275,760,368,792,887,818,788,]
mena_iso_txt = f"iso={mena_iso[0]}"
for m in mena_iso[1:]:
    mena_iso_txt +=f":OR:iso={m}"
    
start_date = datetime.strptime("2023-06-01",'%Y-%m-%d')
response_date = datetime.strptime("2024-10-30",'%Y-%m-%d')

page = 1

while response_date > start_date:
    r = requests.get(f"{url}&{mena_iso_txt}&page={page}")
    page+=1
    data = r.json()["data"]
    response_date = datetime.strptime(data[0]["event_date"], '%Y-%m-%d')
    
    file_name = f'{data[0]["event_date"]}'
    with open(f'data/MENA/{file_name}_{page-1}.json', 'w') as f:
        json.dump(data, f)

# %%
"""
SSA Countries:
Ethiopia - 231,
Somalia - 706,
Eritrea - 232,
Benin - 204,
Burkina Faso - 854,
Sudan - 729,
South Sudan - 728,
Nigeria - 566,
Cameroon - 120,
DRC - 180,
Mozambique - 508,
Senegal - 686,
Kenya - 404,
Ghana - 288,
Togo - 768,
Mali - 466,
"""
ssa_iso = [231,706,232,204,854,729,728,566,120,180,508,686,404,288,768,466,]
ssa_iso_txt = f"iso={ssa_iso[0]}"
for s in ssa_iso[1:]:
    ssa_iso_txt +=f":OR:iso={s}"
start_date = datetime.strptime("2023-06-01",'%Y-%m-%d')
response_date = datetime.strptime("2024-10-30",'%Y-%m-%d')

page = 1

while response_date > start_date:
    r = requests.get(f"{url}&{ssa_iso_txt}&page={page}")
    page+=1
    data = r.json()["data"]
    response_date = datetime.strptime(data[0]["event_date"], '%Y-%m-%d')
    
    file_name = f'{data[0]["event_date"]}'
    with open(f'data/SSA/{file_name}_{page-1}.json', 'w') as f:
        json.dump(data, f)

# %%
"""
CEE CIS Countries:
Ukraine - 804,
Russia - 643,
Belarus - 112,
Serbia - 688,
Kosovo - 0,
Georgia - 268,
Armenia - 51,
Azerbaijan - 31,
"""
cis_iso = [804,643,112,688,0,268,51,31,]
cis_iso_txt = f"iso={cis_iso[0]}"
for c in cis_iso[1:]:
    cis_iso_txt +=f":OR:iso={c}"
    
start_date = datetime.strptime("2023-06-01",'%Y-%m-%d')
response_date = datetime.strptime("2024-10-30",'%Y-%m-%d')

page = 1

while response_date > start_date:
    r = requests.get(f"{url}&{cis_iso_txt}&page={page}")
    page+=1
    data = r.json()["data"]
    response_date = datetime.strptime(data[0]["event_date"], '%Y-%m-%d')
    
    file_name = f'{data[0]["event_date"]}'
    with open(f'data/CIS_CEE/{file_name}_{page-1}.json', 'w') as f:
        json.dump(data, f)

# %%
from os import listdir
from os.path import isfile, join

# %%
mypath = "data/MENA/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]


with open(mypath+onlyfiles[0],"r") as file:
    d = json.load(file)
    df = pd.DataFrame.from_dict(d)

for file_name in onlyfiles[1:]:
    with open(mypath+file_name, "r") as file:
        d = json.load(file)
    df = pd.concat([df, pd.DataFrame.from_dict(d)])
# df = df.reset_index(drop=True)
# df['event_date'] = pd.to_datetime(df['event_date'])
# df['latitude'] = pd.to_numeric(df['latitude'])
# df['longitude'] = pd.to_numeric(df['longitude'])
# df['actor_group'] = df['actor1'].map(actor_map)

# %%
df
# Out:
#      event_id_cnty  event_date  year time_precision       disorder_type  \
# 0         IRN23229  2023-05-09  2023              1      Demonstrations
# 1         LBN14820  2023-05-09  2023              1      Demonstrations
# 2         LBN14822  2023-05-09  2023              1      Demonstrations
# 3         TUR29741  2023-05-09  2023              1      Demonstrations
# 4         TUR29750  2023-05-09  2023              1      Demonstrations
# ...            ...         ...   ...            ...                 ...
# 4995     SYR134229  2024-10-09  2024              1  Political violence
# 4996     SYR134230  2024-10-09  2024              1  Political violence
# 4997     SYR134231  2024-10-09  2024              1  Political violence
# 4998     SYR134234  2024-10-09  2024              1  Political violence
# 4999     SYR134235  2024-10-09  2024              1  Political violence
#
#                       event_type                     sub_event_type  \
# 0                       Protests                   Peaceful protest
# 1                          Riots              Violent demonstration
# 2                          Riots              Violent demonstration
# 3                       Protests                   Peaceful protest
# 4                       Protests                   Peaceful protest
# ...                          ...                                ...
# 4995  Explosions/Remote violence  Shelling/artillery/missile attack
# 4996  Explosions/Remote violence  Shelling/artillery/missile attack
# 4997  Explosions/Remote violence  Shelling/artillery/missile attack
# 4998  Explosions/Remote violence  Shelling/artillery/missile attack
# 4999  Explosions/Remote violence  Shelling/artillery/missile attack
#
#                                  actor1  \
# 0                     Protesters (Iran)
# 1                     Rioters (Lebanon)
# 2                     Rioters (Lebanon)
# 3                   Protesters (Turkey)
# 4                   Protesters (Turkey)
# ...                                 ...
# 4995   Military Forces of Syria (2000-)
# 4996   Military Forces of Syria (2000-)
# 4997   Military Forces of Syria (2000-)
# 4998  Military Forces of Turkey (2016-)
# 4999  Military Forces of Turkey (2016-)
#
#                                           assoc_actor_1  \
# 0                                       Students (Iran)
# 1                         Depositors Outcry Association
# 2     Depositors Outcry Association; Independent Pol...
# 3     Yesil Sol Parti: Green Left Party; HDP: People...
# 4                     Yesil Sol Parti: Green Left Party
# ...                                                 ...
# 4995
# 4996
# 4997
# 4998                          Opposition Rebels (Syria)
# 4999                          Opposition Rebels (Syria)
#
#                      inter1  ...             location latitude longitude  \
# 0                Protesters  ...  Tehran - District 6  35.7252   51.4029
# 1                   Rioters  ...        Beirut - Port  33.8982   35.5074
# 2                   Rioters  ...        Beirut - Port  33.8982   35.5074
# 3                Protesters  ...                Cizre  37.3274   42.1785
# 4                Protesters  ...             Gaziemir  38.3239   27.1292
# ...                     ...  ...                  ...      ...       ...
# 4995           State forces  ...                Taqad  36.1987   36.8698
# 4996           State forces  ...             Kabashin  36.3323   36.9175
# 4997           State forces  ...     Maaret Al Naasan  36.0351   36.8376
# 4998  External/Other forces  ...      Maratet Um Hosh  36.4109   37.2118
# 4999  External/Other forces  ...         Umm al Qarah  36.3805   37.2286
#
#      geo_precision                                    source  \
# 0                1           Trade Unions of Iranian Student
# 1                1  L'Orient Le Jour; Naharnet; The National
# 2                1                         Murr TV; Naharnet
# 3                1                                  ANF News
# 4                1                        Mezopotamya Agency
# ...            ...                                       ...
# 4995             1                        Halab Today; SHAAM
# 4996             2                               Halab Today
# 4997             2                          Liveuamap; SHAAM
# 4998             1                                      SOHR
# 4999             1                                      SOHR
#
#                  source_scale  \
# 0                   New media
# 1      National-International
# 2                    National
# 3               International
# 4                    National
# ...                       ...
# 4995                 National
# 4996                 National
# 4997  Local partner-New media
# 4998                    Other
# 4999                    Other
#
#                                                   notes fatalities  \
# 0     On 9 May 2023, students at the Faculty of Soci...          0
# 1     On 9 May 2023, clashes erupted between demonst...          0
# 2     On 9 May 2023, clashes erupted between police ...          0
# 3     On 9 May 2023, thousands gathered at public me...          0
# 4     On 9 May 2023, Green-Left party members staged...          0
# ...                                                 ...        ...
# 4995  On 9 October 2024, regime forces shelled Taqad...          0
# 4996  On 9 October 2024, regime forces shelled the v...          0
# 4997  On 9 October 2024, regime forces shelled the v...          0
# 4998  On 9 October 2024, Turkish forces supported by...          0
# 4999  On 9 October 2024, Turkish forces supported by...          0
#
#                       tags   timestamp
# 0     crowd size=no report  1684803186
# 1     crowd size=no report  1684803187
# 2     crowd size=no report  1684803187
# 3     crowd size=thousands  1684803190
# 4     crowd size=no report  1684803190
# ...                    ...         ...
# 4995                        1728963308
# 4996                        1728963308
# 4997                        1728963308
# 4998                        1728963308
# 4999                        1728963308
#
# [115000 rows x 31 columns]
